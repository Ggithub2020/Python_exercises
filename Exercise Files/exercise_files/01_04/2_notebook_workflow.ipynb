# %% [markdown]
# # Notebook Workflow

# %% [markdown]
# # Executing Python code

# %% [markdown]
# plotting a function by using a python library called sympy

# %%
# Ensure sympy is installed
# %pip install sympy

from sympy import Symbol, plot

x = Symbol('x')
f = x**2

plot(f)
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#     100 |\                                                     /
#         | .                                                   .
#         |
#         |  .                                                 .
#         |   \                                               /
#         |    .                                             .
#         |
#         |     .                                           .
#         |      \                                         /
#         |       \                                       /
#      50 |--------\-------------------------------------/--------
#         |         \                                   /
#         |          \                                 /
#         |           \                               /
#         |            \                             /
#         |             ..                         ..
#         |               \                       /
# ...

# %%
from sympy import *
x = symbols('x')
f = x**2

plot(f)
# Out:
#     100 |\                                                     /
#         | .                                                   .
#         |
#         |  .                                                 .
#         |   \                                               /
#         |    .                                             .
#         |
#         |     .                                           .
#         |      \                                         /
#         |       \                                       /
#      50 |--------\-------------------------------------/--------
#         |         \                                   /
#         |          \                                 /
#         |           \                               /
#         |            \                             /
#         |             ..                         ..
#         |               \                       /
#         |                ..                   ..
# ...

# %%
from sympy import symbols, plot

# Define the variable and the function
x = symbols('x')
f = x**10

# Plot the function
plot(f, title='Parabola: y = x^20', xlabel='x', ylabel='y')
# Out:
#   1e+10 |.                                                     .
#         |
#         |
#         |
#         |
#         |
#         | .                                                   .
#         |
#         |
#         |
#   5e+09 |-------------------------------------------------------
#         |  .                                                 .
#         |
#         |
#         |   .                                               .
#         |
#         |    .                                             .
#         |     \                                           /
#         |      \                                         /
#         |       ..                                     ..
#       0 |_______________________________________________________
#          -10                        0                          10

# %% [markdown]
# # Show a table using pandas

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.5 MB 3.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.3/11.5 MB 3.2 MB/s eta 0:00:04
#    ------ --------------------------------- 1.8/11.5 MB 3.2 MB/s eta 0:00:03
#    --------- ------------------------------ 2.6/11.5 MB 3.1 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.4/11.5 MB 3.1 MB/s eta 0:00:03
#    ------------- -------------------------- 3.9/11.5 MB 3.2 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.7/11.5 MB 3.2 MB/s eta 0:00:03
#    ------------------ --------------------- 5.2/11.5 MB 3.2 MB/s eta 0:00:02
#    -------------------- ------------------- 6.0/11.5 MB 3.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.8/11.5 MB 3.2 MB/s eta 0:00:02
#    ------------------------- -------------- 7.3/11.5 MB 3.2 MB/s eta 0:00:02
# ...

# %%
import pandas as pd
import requests
# Example usage of pandas to read a CSV file from a URL
url = 'https://raw.githubusercontent.com/thomasnield/machine-learning-demo-data/master/unprocessed/airline_delay_causes.csv'
df = pd.read_csv(url)
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import pandas as pd
#       2 import requests
#       3 # Example usage of pandas to read a CSV file from a URL
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import panda as pd
pd.read_csv('https://raw.githubusercontent.com/thomasnield/machine-learning-demo-data/master/unprocessed/airline_delay_causes.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import panda as pd
#       2 pd.read_csv('https://raw.githubusercontent.com/thomasnield/machine-learning-demo-data/master/unprocessed/airline_delay_causes.csv')
#
# ModuleNotFoundError: No module named 'panda'

# %%
import pandas as pd
pd.read_csv('https://raw.githubusercontent.com/thomasnield/machine-learning-demo-data/master/unprocessed/airline_delay_causes.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import pandas as pd
#       2 pd.read_csv('https://raw.githubusercontent.com/thomasnield/machine-learning-demo-data/master/unprocessed/airline_delay_causes.csv')
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ----- ---------------------------------- 1.6/11.5 MB 8.1 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.1/11.5 MB 9.6 MB/s eta 0:00:01
#    -------------------- ------------------- 5.8/11.5 MB 10.3 MB/s eta 0:00:01
#    ------------------------------ --------- 8.7/11.5 MB 10.5 MB/s eta 0:00:01
#    ------------------------------------- -- 10.7/11.5 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 10.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ------- -------------------------------- 2.4/12.6 MB 11.0 MB/s eta 0:00:01
#    -------------- ------------------------- 4.7/12.6 MB 11.0 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
pd.read_csv('https://raw.githubusercontent.com/thomasnield/machine-learning-demo-data/master/unprocessed/airline_delay_causes.csv')
# Out:
#        year   month carrier           carrier_name airport  \
# 0      2016      11      OO  SkyWest Airlines Inc.     LAR
# 1      2016      11      OO  SkyWest Airlines Inc.     HYS
# 2      2016      11      OO  SkyWest Airlines Inc.     RDD
# 3      2016      11      OO  SkyWest Airlines Inc.     CHS
# 4      2016      11      OO  SkyWest Airlines Inc.     SGF
# ...     ...     ...     ...                    ...     ...
# 65907  2019       1      MQ              Envoy Air     RIC
# 65908  2019       1      MQ              Envoy Air     ROA
# 65909  2019       1      MQ              Envoy Air     ROC
# 65910  2019       1      MQ              Envoy Air     RST
# 65911  2019       1      MQ              Envoy Air     SAT
#
#                                             airport_name  arr_flights  \
# 0                          Laramie, WY: Laramie Regional         51.0
# 1                                Hays, KS: Hays Regional         51.0
# ...

# %%
import pandas as pd
pd.read_csv('https://raw.github.com/Ggithub2020/csv-data-for-PowerBI/blob/master/sales.csv')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 import pandas as pd
# ----> 2 pd.read_csv('https://raw.github.com/Ggithub2020/csv-data-for-PowerBI/blob/master/sales.csv')
#
# ...

# %%
import pandas as pd

# Corrected URL to point to the raw CSV file
pd.read_csv('https://raw.githubusercontent.com/Ggithub2020/csv-data-for-PowerBI/master/sales.csv')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       1 import pandas as pd
#       3 # Corrected URL to point to the raw CSV file
# ----> 4 pd.read_csv('https://raw.githubusercontent.com/Ggithub2020/csv-data-for-PowerBI/master/sales.csv')
#
# ...

# %%
import pandas as pd

# Corrected URL to point to the raw CSV file
url = 'https://raw.githubusercontent.com/thomasnield/machine-learning-demo-data/master/unprocessed/airline_delay_causes.csv'
df = pd.read_csv(url)
print(df.head())
# Out:
#    year   month carrier           carrier_name airport  \
# 0  2016      11      OO  SkyWest Airlines Inc.     LAR
# 1  2016      11      OO  SkyWest Airlines Inc.     HYS
# 2  2016      11      OO  SkyWest Airlines Inc.     RDD
# 3  2016      11      OO  SkyWest Airlines Inc.     CHS
# 4  2016      11      OO  SkyWest Airlines Inc.     SGF
#
#                                     airport_name  arr_flights  arr_del15  \
# 0                  Laramie, WY: Laramie Regional         51.0        1.0
# 1                        Hays, KS: Hays Regional         51.0        5.0
# 2                 Redding, CA: Redding Municipal         90.0       10.0
# 3   Charleston, SC: Charleston AFB/International         68.0       11.0
# 4  Springfield, MO: Springfield-Branson National         78.0        7.0
#
#    carrier_ct   weather_ct  ...  late_aircraft_ct  arr_cancelled  \
# 0        1.00         0.00  ...              0.00            2.0
# ...

# %%
import pandas as pd
pd.read_json('https://github.com/Ggithub2020/SalesVsProfit.Dataset/blob/main/diagramLayout.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 import pandas as pd
# ----> 2 pd.read_json('https://github.com/Ggithub2020/SalesVsProfit.Dataset/blob/main/diagramLayout.json')
#
# File c:\Users\girum\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\json\_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813     return json_reader
#     814 else:
# --> 815     return json_reader.read()
#
# File c:\Users\girum\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\json\_json.py:1025, in JsonReader.read(self)
#    1023         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1024 else:
# ...

# %%
import pandas as pd
pd.read_json('https://raw.github.com/Ggithub2020/SalesVsProfit.Dataset/blob/main/item.config.json')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 import pandas as pd
# ----> 2 pd.read_json('https://raw.github.com/Ggithub2020/SalesVsProfit.Dataset/blob/main/item.config.json')
#
# File c:\Users\girum\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\json\_json.py:791, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     788 if convert_axes is None and orient != "table":
#     789     convert_axes = True
# --> 791 json_reader = JsonReader(
#     792     path_or_buf,
#     793     orient=orient,
#     794     typ=typ,
#     795     dtype=dtype,
#     796     convert_axes=convert_axes,
#     797     convert_dates=convert_dates,
# ...

# %%
import pandas as pd 
pd.read_csv('https://raw.githubusercontent.com/Ggithub2020/csv-data-for-PowerBI/master/sales.csv')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 import pandas as pd
# ----> 2 pd.read_csv('https://raw.githubusercontent.com/Ggithub2020/csv-data-for-PowerBI/master/sales.csv')
#
# ...

# %%
import pandas as pd 
pd.read_csv('https://raw.githubusercontent.com/Ggithub2020/csv-data-for-PowerBI/master/sales.csv')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 import pandas as pd
# ----> 2 pd.read_csv('https://raw.githubusercontent.com/Ggithub2020/csv-data-for-PowerBI/master/sales.csv')
#
# ...

# %%
import pandas as pd
pd.read_csv('https://raw.githubusercontent.com/thomasnield/machine-learning-demo-data/master/unprocessed/airline_delay_causes.csv')
# Out:
#        year   month carrier           carrier_name airport  \
# 0      2016      11      OO  SkyWest Airlines Inc.     LAR
# 1      2016      11      OO  SkyWest Airlines Inc.     HYS
# 2      2016      11      OO  SkyWest Airlines Inc.     RDD
# 3      2016      11      OO  SkyWest Airlines Inc.     CHS
# 4      2016      11      OO  SkyWest Airlines Inc.     SGF
# ...     ...     ...     ...                    ...     ...
# 65907  2019       1      MQ              Envoy Air     RIC
# 65908  2019       1      MQ              Envoy Air     ROA
# 65909  2019       1      MQ              Envoy Air     ROC
# 65910  2019       1      MQ              Envoy Air     RST
# 65911  2019       1      MQ              Envoy Air     SAT
#
#                                             airport_name  arr_flights  \
# 0                          Laramie, WY: Laramie Regional         51.0
# 1                                Hays, KS: Hays Regional         51.0
# ...

# %%
import pandas as pd 
pd.read_csv('https://raw.github.com/Ggithub2020/csv-data-for-PowerBI/blob/master/sales.csv')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 import pandas as pd
# ----> 2 pd.read_csv('https://raw.github.com/Ggithub2020/csv-data-for-PowerBI/blob/master/sales.csv')
#
# ...

# %%
import pandas as pd
pd.read_excel('https://raw.github.com/Ggithub2020/csv-data-for-PowerBI/blob/master/profits.xlsx')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 import pandas as pd
# ----> 2 pd.read_excel('https://raw.github.com/Ggithub2020/csv-data-for-PowerBI/blob/master/profits.xlsx')
#
# File c:\Users\girum\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
# ...

# %%
import pandas as pd
pd.read_json('https://raw.github.com/Ggithub2020/SalesVsProfit.Dataset/blob/main/diagramLayout.json')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 import pandas as pd
# ----> 2 pd.read_json('https://raw.github.com/Ggithub2020/SalesVsProfit.Dataset/blob/main/diagramLayout.json')
#
# File c:\Users\girum\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\json\_json.py:791, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     788 if convert_axes is None and orient != "table":
#     789     convert_axes = True
# --> 791 json_reader = JsonReader(
#     792     path_or_buf,
#     793     orient=orient,
#     794     typ=typ,
#     795     dtype=dtype,
#     796     convert_axes=convert_axes,
#     797     convert_dates=convert_dates,
# ...

# %%
import pandas as pd
pd.read_csv('https://raw.githubusercontent.com/thomasnield/machine-learning-demo-data/master/unprocessed/airline_delay_causes.csv')
# Out:
#        year   month carrier           carrier_name airport  \
# 0      2016      11      OO  SkyWest Airlines Inc.     LAR
# 1      2016      11      OO  SkyWest Airlines Inc.     HYS
# 2      2016      11      OO  SkyWest Airlines Inc.     RDD
# 3      2016      11      OO  SkyWest Airlines Inc.     CHS
# 4      2016      11      OO  SkyWest Airlines Inc.     SGF
# ...     ...     ...     ...                    ...     ...
# 65907  2019       1      MQ              Envoy Air     RIC
# 65908  2019       1      MQ              Envoy Air     ROA
# 65909  2019       1      MQ              Envoy Air     ROC
# 65910  2019       1      MQ              Envoy Air     RST
# 65911  2019       1      MQ              Envoy Air     SAT
#
#                                             airport_name  arr_flights  \
# 0                          Laramie, WY: Laramie Regional         51.0
# 1                                Hays, KS: Hays Regional         51.0
# ...

# %% [markdown]
# ## Rendering Markdown cells

# %% [markdown]
# # Header 1
# ## Header 2
# ### Header 3
# #### Header 4
# ##### Header 5
# ###### Header 6

# %% [markdown]
# | Field 1| Field 2| Field 3|
# | ---|---|---|
# | value 1| value 2| value 3|
# | value 4| value 5| value 6|

# %% [markdown]
# #   we can also make word **Bold** or *Italic* , as wll as ~strikethrogh~

# %% [markdown]
# creating table

# %% [markdown]
# |Field 1|Field 2|Field 3|
# |----|----|----|
# |Value 1|value 2|value 3|
# |value 4|value 5|value 6|

# %% [markdown]
# you can also [create hyperlinks like this](https://learn.microsoft.com)

# %% [markdown]
# creating an image

# %%
# !_[]_(https://i.imgur.com/Gpfl2iZ.jpeg)_
# Out:
# '_[]_' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from IPython.display import Image
Image(url='https://i.imgur.com/Gpfl2iZ.jpeg')
# Out:
# <img src="https://i.imgur.com/Gpfl2iZ.jpeg"/>

# %%
from IPython.display import Image, display

# Display the image
display(Image(url='https://i.imgur.com/Gpfl2iZ.jpeg'))
# Out:
# <img src="https://i.imgur.com/Gpfl2iZ.jpeg"/>

# %% [markdown]
# from IPython.display import Image, display
#
# # Display the image
# display(Image(url='https://i.imgur.com/Gpfl2iZ.jpeg'))

# %%
![Cat Image](https://i.imgur.com/J5LVHEL.jpg)
# Out:
# '[Cat' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from IPython.display import Image, display

# Display the image
display(Image(url='https://i.imgur.com/J5LVHEL.jpg'))
# Out:
# <img src="https://i.imgur.com/J5LVHEL.jpg"/>

# %%
![Ethiopian Flag](https://upload.wikimedia.org/wikipedia/commons/7/71/Flag_of_Ethiopia.svg)
# Out:
# '[Ethiopian' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from IPython.display import Image, display

# Display the Ethiopian flag image
display(Image(url='https://upload.wikimedia.org/wikipedia/commons/7/71/Flag_of_Ethiopia.svg'))
# Out:
# <img src="https://upload.wikimedia.org/wikipedia/commons/7/71/Flag_of_Ethiopia.svg"/>

# %% [markdown]
# #  Math Latex

# %% [markdown]
# $$
# A = \begin{bmatrix} -1 & 1 \\ 0.5 &-2 \end{bmatrix}
# $$
#
# $$
# P(A \cup B) = P(A) + P(B) -P(A) \times P(B)
# $$
#
# $$
# A = \pi r^2
# $$

# %% [markdown]
# !pip install sympy

# %%
! pip install sympy
# Out:
# ...
#   Using cached sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Using cached sympy-1.13.3-py3-none-any.whl (6.2 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# ...

# %%
! pwd
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !pwd
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# # Exercise

# %% [markdown]
# Finish the python code below to plot the function f(x) = 2x3  in this notebook.

# %%
from sympy import *
x = symbols('x')
# finish the code below
f = 2*x**3 
plot(f)
# Out:
#    2000 |                                                      /
#         |                                                     /
#         |                                                    /
#         |                                                   /
#         |                                                  /
#         |                                                ..
#         |                                               /
#         |                                             ..
#         |                                          ...
#         |                                     .....
#       0 |------------------...................------------------
#         |             .....
#         |          ...
#         |        ..
#         |       /
#         |     ..
#         |    /
#         |   /
#         |  /
#         | /
#   -2000 |_______________________________________________________
#          -10                        0                          10

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Set the rate parameter (lambda)
lambda_param = 1.0  # Rate parameter

# Step 2: Generate random samples from the exponential distribution
samples = np.random.exponential(1/lambda_param, 1000)

# Step 3: Create the histogram of the samples
plt.hist(samples, bins=30, density=True, alpha=0.6, color='g', label='Histogram of Samples')

# Step 4: Overlay the theoretical PDF
x = np.linspace(0, np.max(samples), 1000)
pdf = lambda_param * np.exp(-lambda_param * x)
plt.plot(x, pdf, 'r', linewidth=2, label='PDF of Exponential Distribution')

# Step 5: Add labels and legend
plt.title('Exponential Distribution')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()

# Step 6: Show the plot
plt.show()

# %%
pip install  matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ----------- ---------------------------- 2.4/8.0 MB 11.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/8.0 MB 11.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.1/8.0 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 10.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ------------------------------------- -- 2.1/2.2 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 9.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    --------------------------- ------------ 1.8/2.6 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 8.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
